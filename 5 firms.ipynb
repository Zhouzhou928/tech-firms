# %%
# !pip install wrds pandas plotly streamlit numpy
# Out:
# Requirement already satisfied: wrds in /opt/anaconda3/lib/python3.13/site-packages (3.5.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.13/site-packages (6.3.0)
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.13/site-packages (1.51.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.3.5)
# Requirement already satisfied: ipython<=9.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from wrds) (9.7.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /opt/anaconda3/lib/python3.13/site-packages (from wrds) (2.9.11)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from wrds) (2.0.43)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<=9.8.0->wrds) (5.14.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<=9.8.0->wrds) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.15.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (25.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.18.1->ipython<=9.8.0->wrds) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython<=9.8.0->wrds) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
# Import required libraries
import wrds
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

# %%
# Connect to WRDS database
db = wrds.Connection(wrds_username="zhouzhou928")
# Out:
# Loading library list...
# Done

# %%
query = '''
SELECT tic, conm, fyear, revt, ni, at, lt, act, lct, seq
FROM comp.funda
WHERE tic IN ('AAPL','MSFT','GOOGL','AMZN','META')
AND fyear BETWEEN 2015 AND 2023
AND indfmt='INDL' AND datafmt='STD' AND consol='C'
ORDER BY tic, fyear;
'''

df = db.raw_sql(query)
df['year'] = df['fyear'].astype(int)

# %%
# Show clean data table
print("Raw Data from WRDS")
display(df.head(10))
# Out:
# Raw Data from WRDS
#     tic            conm  fyear      revt       ni        at        lt  \
# 0  AAPL       APPLE INC   2015  233715.0  53394.0  290479.0  171124.0
# 1  AAPL       APPLE INC   2016  215091.0  45687.0  321686.0  193437.0
# 2  AAPL       APPLE INC   2017  229234.0  48351.0  375319.0  241272.0
# 3  AAPL       APPLE INC   2018  265359.0  59531.0  365725.0  258578.0
# 4  AAPL       APPLE INC   2019  260174.0  55256.0  338516.0  248028.0
# 5  AAPL       APPLE INC   2020  274515.0  57411.0  323888.0  258549.0
# 6  AAPL       APPLE INC   2021  365817.0  94680.0  351002.0  287912.0
# 7  AAPL       APPLE INC   2022  394328.0  99803.0  352755.0  302083.0
# 8  AAPL       APPLE INC   2023  383285.0  96995.0  352583.0  290437.0
# 9  AMZN  AMAZON.COM INC   2015  107006.0    596.0   65444.0   52060.0
#
#         act       lct       seq  year
# 0   89378.0   80610.0  119355.0  2015
# 1  106869.0   79006.0  128249.0  2016
# 2  128645.0  100814.0  134047.0  2017
# 3  131339.0  116866.0  107147.0  2018
# 4  162819.0  105718.0   90488.0  2019
# 5  143713.0  105392.0   65339.0  2020
# 6  134836.0  125481.0   63090.0  2021
# 7  135405.0  153982.0   50672.0  2022
# 8  143566.0  145308.0   62146.0  2023
# 9   36474.0   33899.0   13384.0  2015

# %%
# Calculate financial ratios
df['profit_margin'] = (df['ni'] / df['revt']) * 100
df['roe'] = (df['ni'] / df['seq']) * 100
df['roa'] = (df['ni'] / df['at']) * 100
df['debt_asset'] = (df['lt'] / df['at']) * 100
df['current_ratio'] = df['act'] / df['lct']
df['revt_growth'] = df.groupby('tic')['revt'].pct_change() * 100

# %%
# Create industry benchmark
industry = df.groupby('year').agg({
    'revt':'mean', 'ni':'mean', 'profit_margin':'mean',
    'roe':'mean', 'roa':'mean'
}).reset_index()

industry['tic'] = 'INDUSTRY'
industry['conm'] = 'TECH INDUSTRY AVERAGE'

# %%
# Merge company data and industry data
final_df = pd.concat([df, industry], ignore_index=True)

# %%
# Show 2023 summary table
summary_2023 = final_df[final_df['year'] == 2023][[
    'tic','conm','revt','ni','profit_margin','roe','roa'
]].round(2)

print("2023 Financial Performance Summary")
display(summary_2023)
# Out:
# 2023 Financial Performance Summary
#          tic                   conm      revt       ni  profit_margin     roe  \
# 8       AAPL              APPLE INC  383285.0  96995.0          25.31  156.08
# 17      AMZN         AMAZON.COM INC  574785.0  30425.0           5.29   15.07
# 26     GOOGL           ALPHABET INC  307394.0  73795.0          24.01   26.25
# 35      META     META PLATFORMS INC  134902.0  39098.0          28.98   25.53
# 44      MSFT         MICROSOFT CORP  211915.0  72361.0          34.15   35.09
# 53  INDUSTRY  TECH INDUSTRY AVERAGE  322456.2  62534.8          23.55    51.6
#
#       roa
# 8   27.51
# 17   5.76
# 26  18.34
# 35  17.03
# 44  17.56
# 53  17.24

# %%
# Save data for Streamlit dashboard
final_df.to_csv('tech_finance_5firms.csv', index=False)
print("✅ Data saved successfully")
# Out:
# ✅ Data saved successfully

# %%
# Plot 1: Net Profit Margin Trend
fig = px.line(final_df, x='year', y='profit_margin', color='tic',
              markers=True, template='plotly_white',
              title='Net Profit Margin 2015-2023')
fig.show()

# %%
# Plot 2: ROE Comparison
fig = px.bar(final_df, x='year', y='roe', color='tic',
             barmode='group', template='plotly_white',
             title='ROE Comparison')
fig.show()

# %%
# Plot 3: ROE vs Profit Margin Scatter
fig = px.scatter(final_df, x='roe', y='profit_margin',
                 color='tic', size='revt',
                 template='plotly_white',
                 title='ROE vs Profit Margin')
fig.show()

# %%
# Plot 4: 2023 Financial Radar Chart
latest = final_df[final_df['year'] == 2023]
fig = go.Figure()

for _, r in latest.iterrows():
    fig.add_trace(go.Scatterpolar(
        r=[r.profit_margin, r.roe, r.roa, 100-r.debt_asset],
        theta=['Profit Margin','ROE','ROA','Low Debt'],
        fill='toself', name=r.tic
    ))

fig.update_layout(title='2023 Financial Strength Radar')
fig.show()

# %%
# Plot 5: Correlation Heatmap
corr = df[['profit_margin','roe','roa','debt_asset']].corr()
fig = px.imshow(corr, text_auto=True, color_continuous_scale='RdBu_r')
fig.show()

# %%
# !streamlit run app.py
# Out:
#       👋 Welcome to Streamlit!
#
#       If you'd like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:
